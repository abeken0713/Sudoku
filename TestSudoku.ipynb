# %%
import numpy  as np
import matplotlib.pyplot as plt
from Sudoku import Sudoku
# %matplotlib inline

# %%
s = """
400000060
500032004
910004000
000600450
200015006
000000010
008000620
000800540
070000100
"""

# %%
m = Sudoku(s)

# %%
m.plotTable()

# %%
m.updateDraft()

# %%
m.plotTable()

# %%
m.fill(1, 3, 1)
m.plotTable()
# Out:
# Filled 1 to [1,3]

# %%
m.draft[3, 0, [0, 2]] = False
m.draft[5, 0, [0, 2]] = False

# %%
m.fill(3, 2, 1)
m.plotTable()
# Out:
# Filled 1 to [3,2]

# %%
m.fill(0, 8, 1)
# Out:
# Filled 1 to [0,8]

# %%
m.plotTable()

# %%
m.fill(2, 4, 6)
m.plotTable()
# Out:
# Filled 6 to [2,4]

# %%
m.fill(2, 8, 5)
m.plotTable()
# Out:
# Filled 5 to [2,8]

# %%
m.fill(2, 3, 7)
m.plotTable()
# Out:
# Filled 7 to [2,3]

# %%
m.fill(0, 2, 7)
m.fill(1, 1, 8)
m.fill(1, 2, 6)
m.plotTable()
# Out:
# Filled 7 to [0,2]
# Filled 8 to [1,1]
# Filled 6 to [1,2]

# %%
m.fill(5, 2, 5)
m.fill(5, 1, 6)
m.fill(8, 2, 4)
m.fill(6, 1, 5)
m.plotTable()
# Out:
# Filled 5 to [5,2]
# Filled 6 to [5,1]
# Filled 4 to [8,2]
# Filled 5 to [6,1]

# %%
m.fill(4, 1, 4)
m.plotTable()
# Out:
# Filled 4 to [4,1]

# %%
m.fill(7, 4, 7)
m.plotTable()
# Out:
# Filled 7 to [7,4]

# %%
m.fill(7, 8, 3)
m.plotTable()
# Out:
# Filled 3 to [7,8]

# %%
m.fill(6, 8, 7)
m.plotTable()
# Out:
# Filled 7 to [6,8]

# %%
s2 = """
437500261
586132974
912764835
091600452
243915786
065000319
058000627
029870543
074250198
"""
m2 = Sudoku(s2)
m2.plotTable()

# %%
m2.updateDraft()

# %%
m2.plotTable()
